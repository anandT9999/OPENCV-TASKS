# %% [markdown]
# <a href="https://colab.research.google.com/github/anandT9999/OPENCV-TASKS/blob/main/Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread("/content/Michele.Richard@aecom.com--RFJ_SL1416935_MH3754622231_20161130_0626_68.0--18-08-2022.jpg")
plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("/content/Michele.Richard@aecom.com--RFJ_SL1416935_MH3754622231_20161130_0626_68.0--18-08-2022.jpg")
plt.imshow(img)

# %%
import xml.etree.ElementTree as ET
mytree = ET.parse('/content/Michele.Richard@aecom.com--RFJ_SL1416935_MH3754622231_20161130_0626_68.0--18-08-2022.xml')

# %%
myroot = mytree.getroot()
print(myroot)
# Out:
# <Element 'annotation' at 0x7fd00a5c90b0>

# %%
from PIL import Image
im = Image.open('/content/Michele.Richard@aecom.com--RFJ_SL1416935_MH3754622231_20161130_0626_68.0--18-08-2022.jpg')
im.show()
plt.imshow(im)

# %%
import cv2
import numpy as np

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img_path = r"/content/Michele.Richard@aecom.com--RFJ_SL1416935_MH3754622231_20161130_0626_68.0--18-08-2022.jpg"
image = cv2.imread(img_path)
image = cv2.resize(image , (1280,720))

pt1 = (120,94)
pt2 = (445,424)
color = (0,255,0)
thickness = 7
lineType = cv2.LINE_4

img_rect= cv2.rectangle(image , pt1 , pt2 , color , thickness ,lineType)
plt.imshow(img_rect)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# TEXT ON ANNOTATION

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img_path = r"/content/Michele.Richard@aecom.com--RFJ_SL1416935_MH3754622231_20161130_0626_68.0--18-08-2022.jpg"
image = cv2.imread(img_path)
image = cv2.resize(image , (1280,720))

pt1 = (120,94)
pt2 = (445,424)
color = (0,255,0)
thickness = 7
lineType = cv2.LINE_4

img_rect= cv2.rectangle(image , pt1 , pt2 , color , thickness ,lineType)

text = "RFJ"
org = (100,75)
fontFace = cv2.FONT_HERSHEY_COMPLEX
fontScale = 2
color = (255,0,0)
lineType= cv2.LINE_4
img_text=cv2.putText(img_rect, text, org, fontFace, fontScale, color, lineType)

plt.imshow(img_text)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img_path = r"/content/Michele.Richard@aecom.com--RFJ_SL1416935_MH3754622231_20161130_0626_68.0--18-08-2022.jpg"
image = cv2.imread(img_path)
image = cv2.resize(image , (1280,720))

pt1 = (120,94)
pt2 = (445,424)
color = (0,255,0)
thickness = 7
lineType = cv2.LINE_4

img_rect= cv2.rectangle(image , pt1 , pt2 , color , thickness ,lineType)

pt1 = (639,110)
pt2 = (820,306)
color = (0,255,0)
thickness = 7
lineType = cv2.LINE_4
img_rect= cv2.rectangle(image , pt1 , pt2 , color , thickness ,lineType)

text = "RFJ"
org = (100,75)
fontFace = cv2.FONT_HERSHEY_COMPLEX
fontScale = 2
color = (255,0,0)
lineType= cv2.LINE_4
img_text=cv2.putText(img_rect, text, org, fontFace, fontScale, color, lineType)


text = "RFJ"
org = (629,75)
fontFace = cv2.FONT_HERSHEY_COMPLEX
fontScale = 2
color = (255,0,0)
lineType= cv2.LINE_4
img_text=cv2.putText(img_rect, text, org, fontFace, fontScale, color, lineType)
plt.imshow(img_text)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img_path = r"/content/Michele.Richard@aecom.com--RFJ_SL1416935_MH3754622231_20161130_0626_68.0--18-08-2022.jpg"
image = cv2.imread(img_path)
image = cv2.resize(image , (1280,720))

pt1 = (120,94)
pt2 = (445,424)
color = (0,255,0)
thickness = 7
lineType = cv2.LINE_4

img_rect= cv2.rectangle(image , pt1 , pt2 , color , thickness ,lineType)

pt1 = (639,110)
pt2 = (820,306)
color = (0,255,0)
thickness = 7
lineType = cv2.LINE_4
img_rect= cv2.rectangle(image , pt1 , pt2 , color , thickness ,lineType)

pt1 = (544,622)
pt2 = (753,793)
color = (0,255,0)
thickness = 7
lineType = cv2.LINE_4
img_rect= cv2.rectangle(image , pt1 , pt2 , color , thickness ,lineType)

text = "RFJ"
org = (100,75)
fontFace = cv2.FONT_HERSHEY_COMPLEX
fontScale = 2
color = (255,0,0)
lineType= cv2.LINE_4
img_text=cv2.putText(img_rect, text, org, fontFace, fontScale, color, lineType)


text = "RFJ"
org = (629,75)
fontFace = cv2.FONT_HERSHEY_COMPLEX
fontScale = 2
color = (255,0,0)
lineType= cv2.LINE_4
img_text=cv2.putText(img_rect, text, org, fontFace, fontScale, color, lineType)

text = "Distance_NU"
org = (520,590)
fontFace = cv2.FONT_HERSHEY_COMPLEX
fontScale = 1
color = (255,0,0)
lineType= cv2.LINE_4
img_text=cv2.putText(img_rect, text, org, fontFace, fontScale, color, lineType)


plt.imshow(img_text)
cv2.waitKey(0)
cv2.destroyAllWindows()
